# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data = {
    "Student_ID": [101,102,103,104,105,106,107,108,109,110,
                   111,112,113,114,115,116,117,118,119,120],

    "Name": ["Arun","Bala","Charan","Divya","Esha",
             "Farhan","Gayathri","Hari","Isha","Jagan",
             "Kavya","Lokesh","Meena","Naveen","Oviya",
             "Prakash","Riya","Santhosh","Tanya","Vikram"],

    "Gender": ["M","M","M","F","F",
               "M","F","M","F","M",
               "F","M","F","M","F",
               "M","F","M","F","M"],

    "Age": [20,21,19,20,22,
            21,20,23,19,22,
            21,20,22,19,20,
            21,22,23,19,22],

    "Math": [85,78,92,88,None,
             75,90,68,86,79,
             93,84,88,76,91,
             69,87,82,94,77],

    "Science": [90,82,89,None,91,
                78,92,72,88,80,
                95,81,90,74,89,
                70,85,84,96,79],

    "English": [88,76,84,90,87,
                80,91,70,89,77,
                92,79,85,72,93,
                68,88,80,95,75],

    "Attendance": [95,88,92,98,85,
                   82,96,75,94,83,
                   99,87,91,80,97,
                   78,90,86,99,84]
}

# %%
df = pd.DataFrame(data)

# %%
df.head(20)
# Out:
#     Student_ID      Name Gender  Age  Math  Science  English  Attendance
# 0          101      Arun      M   20  85.0     90.0       88          95
# 1          102      Bala      M   21  78.0     82.0       76          88
# 2          103    Charan      M   19  92.0     89.0       84          92
# 3          104     Divya      F   20  88.0      NaN       90          98
# 4          105      Esha      F   22   NaN     91.0       87          85
# 5          106    Farhan      M   21  75.0     78.0       80          82
# 6          107  Gayathri      F   20  90.0     92.0       91          96
# 7          108      Hari      M   23  68.0     72.0       70          75
# 8          109      Isha      F   19  86.0     88.0       89          94
# 9          110     Jagan      M   22  79.0     80.0       77          83
# 10         111     Kavya      F   21  93.0     95.0       92          99
# 11         112    Lokesh      M   20  84.0     81.0       79          87
# ...

# %%
df.shape
# Out:
# (20, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  20 non-null     int64
#  1   Name        20 non-null     object
#  2   Gender      20 non-null     object
#  3   Age         20 non-null     int64
#  4   Math        19 non-null     float64
#  5   Science     19 non-null     float64
#  6   English     20 non-null     int64
#  7   Attendance  20 non-null     int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 1.4+ KB

# %%
df.describe()
# Out:
#        Student_ID        Age       Math    Science    English  Attendance
# count    20.00000  20.000000  19.000000  19.000000  20.000000   20.000000
# mean    110.50000  20.800000  83.263158  84.473684  82.950000   88.950000
# std       5.91608   1.321881   7.837532   7.611164   8.088165    7.279929
# min     101.00000  19.000000  68.000000  70.000000  68.000000   75.000000
# 25%     105.75000  20.000000  77.500000  79.500000  76.750000   83.750000
# 50%     110.50000  21.000000  85.000000  85.000000  84.500000   89.000000
# 75%     115.25000  22.000000  89.000000  90.000000  89.250000   95.250000
# max     120.00000  23.000000  94.000000  96.000000  95.000000   99.000000

# %%
df['Total'] = df['Math'] + df['Science'] +df['English']

# %%
df.head()
# Out:
#    Student_ID    Name Gender  Age  Math  Science  English  Attendance  Total
# 0         101    Arun      M   20  85.0     90.0       88          95  263.0
# 1         102    Bala      M   21  78.0     82.0       76          88  236.0
# 2         103  Charan      M   19  92.0     89.0       84          92  265.0
# 3         104   Divya      F   20  88.0      NaN       90          98    NaN
# 4         105    Esha      F   22   NaN     91.0       87          85    NaN

# %%
df[['Math','Science','English']].mean()
# Out:
# Math       83.263158
# Science    84.473684
# English    82.950000
# dtype: float64

# %%
df['Average'] = df['Total'] /3

# %%
df.head()
# Out:
#    Student_ID    Name Gender  Age  Math  Science  English  Attendance  Total  \
# 0         101    Arun      M   20  85.0     90.0       88          95  263.0
# 1         102    Bala      M   21  78.0     82.0       76          88  236.0
# 2         103  Charan      M   19  92.0     89.0       84          92  265.0
# 3         104   Divya      F   20  88.0      NaN       90          98    NaN
# 4         105    Esha      F   22   NaN     91.0       87          85    NaN
#
#      Average
# 0  87.666667
# 1  78.666667
# 2  88.333333
# 3        NaN
# 4        NaN

# %%
df['Result'] = df['Average'].apply(lambda x: 'Excellent' if x>=80 else 'Good')

# %%
df['Grade'] =df['Average'].apply(lambda x:'0' if x>90
                                 else 'A' if x>80
                                 else 'B' if x>70
                                 else 'C' if x>60
                                 else 'D' if x>50
                                 else'F')

# %%
df.isnull().sum()
# Out:
# Student_ID    0
# Name          0
# Gender        0
# Age           0
# Math          1
# Science       1
# English       0
# Attendance    0
# Total         2
# Average       2
# Result        0
# Grade         0
# dtype: int64

# %%
df['Math'] = df['Math'].fillna(df['Math'].mean())

# %% [markdown]
# df['Science']= df['Science'].fillna(df['Science'].mean())

# %%
df.isnull().sum()
# Out:
# Student_ID    0
# Name          0
# Gender        0
# Age           0
# Math          0
# Science       1
# English       0
# Attendance    0
# Total         2
# Average       2
# Result        0
# Grade         0
# dtype: int64

# %%
df['Science']=df['Science'].fillna(df['Science'].mean())

# %%
df.isnull().sum()
# Out:
# Student_ID    0
# Name          0
# Gender        0
# Age           0
# Math          0
# Science       0
# English       0
# Attendance    0
# Total         2
# Average       2
# Result        0
# Grade         0
# dtype: int64

# %%
df['Total'] = df['Math'] + df['Science'] + df['English']

# %%
df['Average'] = df['Total'] /3

# %%
df.isnull().sum()
# Out:
# Student_ID    0
# Name          0
# Gender        0
# Age           0
# Math          0
# Science       0
# English       0
# Attendance    0
# Total         0
# Average       0
# Result        0
# Grade         0
# dtype: int64

# %%
df[['Math','Science','English']].mean()
# Out:
# Math       83.263158
# Science    84.473684
# English    82.950000
# dtype: float64

# %%
df.sort_values(by='Total',ascending=False) [['Name','Total']].head(20)
# Out:
#         Name       Total
# 18     Tanya  285.000000
# 10     Kavya  280.000000
# 14     Oviya  273.000000
# 6   Gayathri  273.000000
# 2     Charan  265.000000
# 8       Isha  263.000000
# 12     Meena  263.000000
# 0       Arun  263.000000
# 3      Divya  262.473684
# 4       Esha  261.263158
# 16      Riya  260.000000
# 17  Santhosh  246.000000
# 11    Lokesh  244.000000
# 9      Jagan  236.000000
# 1       Bala  236.000000
# 5     Farhan  233.000000
# 19    Vikram  231.000000
# 13    Naveen  222.000000
# 7       Hari  210.000000
# 15   Prakash  207.000000

# %%
df.sort_values(by='Total')[['Name']].head()
# Out:
#        Name
# 15  Prakash
# 7      Hari
# 13   Naveen
# 19   Vikram
# 5    Farhan

# %%
df['Gender'].value_counts()
# Out:
# Gender
# M    11
# F     9
# Name: count, dtype: int64

# %%
sns.countplot(x='Gender',data=df)
plt.show()

# %%
sns.histplot(df['Age'],bins=5)
plt.show()

# %%
df['Attendance'].describe()
# Out:
# count    20.000000
# mean     88.950000
# std       7.279929
# min      75.000000
# 25%      83.750000
# 50%      89.000000
# 75%      95.250000
# max      99.000000
# Name: Attendance, dtype: float64

# %%
sns.scatterplot(x='Attendance',y='Total',data=df)
plt.show()

# %%
corr=df[['Math','Science','English','Attendance']].corr()

plt.figure(figsize=(8,5))
sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.show()

# %%
sns.boxplot(y=df['Math'])
plt.show()

# %%
sns.boxplot(y=df['Science'])
plt.show()

# %%
sns.boxplot(y=df['English'])
plt.show()

# %%
sns.boxplot(y=df['Science'])
plt.show()

# %%
df['Grade'].value_counts()
# Out:
# Grade
# A    7
# B    5
# 0    4
# F    2
# C    2
# Name: count, dtype: int64

# %%
sns.countplot(x='Grade',data=df,order=['o','A','B','C','D','F'])
plt.show()
